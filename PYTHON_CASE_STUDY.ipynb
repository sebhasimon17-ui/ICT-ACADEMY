# %% [markdown]
# #1. Bank Account Manager
# a. Simulate a bank account with deposit, withdrawal, and balance
# enquiry operations
#
# b. Use variables and data types to store account information
#
# c. Implement conditional statements to check for sufficient balance
# before withdrawal
#
# d. Use functions to perform deposit, withdrawal, and balance inquiry

# %%
balance = 1000

def deposit(balance, amount):
    balance = balance + amount
    return balance

def withdraw(balance, amount):
    if amount <= balance:
        balance = balance - amount
        return balance
    else:
        print("Insufficient balance")
        return balance

def check_balance(balance):
    print("Current balance:", balance)


balance = deposit(balance, 500)
print("After deposit:", balance)

balance = withdraw(balance, 300)
print("After withdrawal:", balance)

check_balance(balance)
# Out:
# After deposit: 1500
# After withdrawal: 1200
# Current balance: 1200

# %% [markdown]
# #2. Weather Data Analyzer
# a. Analyze weather data (temperature, humidity, etc.) for a given region
#
# b. Use variables and data types to store weather data
#
# c. Implement conditional statements to determine weather conditions
# (sunny, rainy, etc.)
#
# d. Use functions to calculate average temperature and humidity, and
# print results

# %%
#feom statistics import mean , median , mode

temperature = [17,18,13,24,30,20]

from statistics import mean, median, mode

temperature = [17, 18, 13, 24, 30, 20]
humidity = [60, 65, 60, 70, 75, 68]

print("Mean Temperature:", mean(temperature))
print("Median Temperature:", median(temperature))
print("Mode Temperature:", mode(temperature))
# Out:
# Mean Temperature: 20.333333333333332
# Median Temperature: 19.0
# Mode Temperature: 17

# %% [markdown]
# #3. Password Validator
# Write a function that checks if a password is strong: at least 8 characters,
# contains at least one digit, one uppercase letter, and one special character

# %%
#password validator

password = input("Enter password: ")
if len(password) >= 8 and any(i.isdigit() for i in password) and any(i.isupper()
 for i in password) and any(i in "!@#$%" for i in password):
    print("Strong Password")
else:
    print("Weak Password")
# Out:
# Enter password: sheabasimon
# Weak Password

# %% [markdown]
# #4. Word Frequency Counter
# Given a paragraph of text, write a function that returns the 3 most
# frequently occurring words (ignore case and punctuation)

# %%
from collections import Counter

text = input("Enter paragraph: ")
words = text.lower().split()

count = Counter(words)

print(count.most_common(3))
# Out:
# Enter paragraph: Python is easy and Python is powerful. Python is popular and easy to learn.
# [('python', 3), ('is', 3), ('easy', 2)]

# %% [markdown]
# #FizzBuzz Variant
# Print numbers 1 to 50, but replace multiples of 3 with "Fizz", multiples of 5
# with "Buzz", multiples of both with "FizzBuzz" — and multiples of 7 with
# "Bang".

# %%
for i in range(1, 51):
    if i % 3 == 0 and i % 5 == 0:
        print("FizzBuzz")
    elif i % 3 == 0:
        print("Fizz")
    else:
        print(i)
# Out:
# 1
# 2
# Fizz
# 4
# 5
# Fizz
# 7
# 8
# Fizz
# 10
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# 20
# Fizz
# 22
# 23
# Fizz
# 25
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# 35
# Fizz
# 37
# 38
# Fizz
# 40
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# 50
